# %%
var1 = eval(input("agrega una variable int:"))
var2 = eval(input("agrega una variable float:"))
var3 = input("agrega una variable str:")

print (var1)
print (var2)
print (var3)

print(type(var1))
print(type(var2))
print(type(var3))
# Out:
# agrega una variable int: 531813
# agrega una variable float: 1254.1818
# agrega una variable str: db hb jfhydbcsd
# 531813
# 1254.1818
# db hb jfhydbcsd
# <class 'int'>
# <class 'float'>
# <class 'str'>
